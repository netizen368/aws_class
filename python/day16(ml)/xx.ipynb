# %%
# A = w1x1 + w2x2
# B = w3x1 + w4x2
# Y = w5A + w6B
# Y = w5(w1x1 + w2x2) + w6(w3x1 + w4x2)
#   = w1w5x1 + w2w5x2 + 
#     w3w6x1 + w4w6x2
#   = (w1w5 + w3w6)x1 + 
#     (w2w5 + w4w6)x2
#   = w7x1 + w8x2
