# %%
# CIFAR : 캐나다 고등 연구소 약자
# 10 : 분류 10개
# - 비행기, 자동차, 새, 고양이, 사슴, 개, 개구리, 말, 배, 트럭
# 이미지 총 6만장. 학습 5만, 테스트 1만
# 크기 32 x 32

# %%
# 데이터 생성, 독립/종속 분리, 훈련/테스트 분리
import tensorflow as tf
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
# 10가지 분류명(확인용)
class_names = [
	'airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck'
]

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# 콜백
callbacks = [
	EarlyStopping(monitor='val_loss', patience=5,restore_best_weights=True),
	ModelCheckpoint(filepath='best_cifar10_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1),
	ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
]

# %%
# 파이프라인
from tensorflow.data import Dataset

DATASET_SIZE = 50000
TRAIN_SIZE = int(DATASET_SIZE * 0.8)
VAL_SIZE = int(DATASET_SIZE * 0.2)

dataset = Dataset.from_tensor_slices((X_train, y_train))
# 섞음 
dataset = dataset.shuffle(buffer_size=DATASET_SIZE)
# 훈련 데이터셋
train_dataset = dataset.take(TRAIN_SIZE)
# 검증 데이터셋
val_dataset = dataset.skip(TRAIN_SIZE)

train_dataset = train_dataset.batch(128).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(128).prefetch(tf.data.AUTOTUNE)

# %%
# 데이터 증강 : 이미지를 돌리거나, 색상 반전등과 같이 변형을 한 복사본을 만들어 학습
data_augmentation = tf.keras.Sequential([
	tf.keras.layers.RandomFlip("horizontal"), # 좌우 반전
	tf.keras.layers.RandomRotation(0.2) # 20% 범위 내에서 무작위 회전
])

# %%
# 모델 설계
model = tf.keras.models.Sequential([
	tf.keras.Input((32, 32, 3)),
	# 데이터 증강 
	# data_augmentation, 
	# 정규화
	tf.keras.layers.Rescaling(1./255),

	tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Dropout(0.25),
	# 이 때 이미지 크기 16 x 16

	# 블록 2
	tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Dropout(0.25),
	# 이 때 이미지 크기 8 x 8

	# 블록 3
	tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.GlobalAveragePooling2D(),

	# 분류기
	tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 모델 설정
model.compile(
	optimizer='adam', 
	loss='sparse_categorical_crossentropy', 
	metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# 학습
history = model.fit(
	train_dataset,
	epochs = 50,
	verbose = 1,
	validation_data=val_dataset,
	callbacks = callbacks,
	batch_size=128,
)
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.4188 - loss: 1.5845
# Epoch 1: val_accuracy improved from None to 0.10610, saving model to best_cifar10_model.keras
#
# Epoch 1: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 150s 433ms/step - accuracy: 0.5003 - loss: 1.3761 - val_accuracy: 0.1061 - val_loss: 4.1725 - learning_rate: 0.0010
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.6210 - loss: 1.0733
# Epoch 2: val_accuracy improved from 0.10610 to 0.57330, saving model to best_cifar10_model.keras
#
# Epoch 2: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 132s 420ms/step - accuracy: 0.6347 - loss: 1.0346 - val_accuracy: 0.5733 - val_loss: 1.1469 - learning_rate: 0.0010
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.6764 - loss: 0.9159
# Epoch 3: val_accuracy improved from 0.57330 to 0.58150, saving model to best_cifar10_model.keras
#
# Epoch 3: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 133s 426ms/step - accuracy: 0.6793 - loss: 0.9042 - val_accuracy: 0.5815 - val_loss: 1.2149 - learning_rate: 0.0010
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.7036 - loss: 0.8406
# Epoch 4: val_accuracy improved from 0.58150 to 0.71030, saving model to best_cifar10_model.keras
#
# Epoch 4: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 134s 426ms/step - accuracy: 0.7091 - loss: 0.8220 - val_accuracy: 0.7103 - val_loss: 0.8116 - learning_rate: 0.0010
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.7349 - loss: 0.7579
# Epoch 5: val_accuracy did not improve from 0.71030
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 112s 357ms/step - accuracy: 0.7355 - loss: 0.7537 - val_accuracy: 0.7075 - val_loss: 0.8203 - learning_rate: 0.0010
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.7561 - loss: 0.7006
# Epoch 6: val_accuracy improved from 0.71030 to 0.78200, saving model to best_cifar10_model.keras
#
# Epoch 6: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 245ms/step - accuracy: 0.7559 - loss: 0.6975 - val_accuracy: 0.7820 - val_loss: 0.6201 - learning_rate: 0.0010
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step - accuracy: 0.7688 - loss: 0.6648
# Epoch 7: val_accuracy did not improve from 0.78200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 89s 283ms/step - accuracy: 0.7691 - loss: 0.6603 - val_accuracy: 0.7132 - val_loss: 0.8291 - learning_rate: 0.0010
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.7880 - loss: 0.6098
# Epoch 8: val_accuracy did not improve from 0.78200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 93s 298ms/step - accuracy: 0.7862 - loss: 0.6128 - val_accuracy: 0.7629 - val_loss: 0.6878 - learning_rate: 0.0010
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.7988 - loss: 0.5766
# Epoch 9: val_accuracy did not improve from 0.78200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 87s 276ms/step - accuracy: 0.7947 - loss: 0.5866 - val_accuracy: 0.7775 - val_loss: 0.6379 - learning_rate: 0.0010
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 264ms/step - accuracy: 0.8201 - loss: 0.5293
# Epoch 10: val_accuracy improved from 0.78200 to 0.83050, saving model to best_cifar10_model.keras
#
# Epoch 10: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 88s 281ms/step - accuracy: 0.8189 - loss: 0.5255 - val_accuracy: 0.8305 - val_loss: 0.4835 - learning_rate: 5.0000e-04
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step - accuracy: 0.8264 - loss: 0.5022
# Epoch 11: val_accuracy improved from 0.83050 to 0.85260, saving model to best_cifar10_model.keras
#
# Epoch 11: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 86s 274ms/step - accuracy: 0.8252 - loss: 0.5026 - val_accuracy: 0.8526 - val_loss: 0.4338 - learning_rate: 5.0000e-04
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.8337 - loss: 0.4790
# Epoch 12: val_accuracy did not improve from 0.85260
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 248ms/step - accuracy: 0.8306 - loss: 0.4877 - val_accuracy: 0.8492 - val_loss: 0.4321 - learning_rate: 5.0000e-04
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.8358 - loss: 0.4728
# Epoch 13: val_accuracy improved from 0.85260 to 0.85380, saving model to best_cifar10_model.keras
#
# Epoch 13: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 251ms/step - accuracy: 0.8359 - loss: 0.4752 - val_accuracy: 0.8538 - val_loss: 0.4222 - learning_rate: 5.0000e-04
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.8430 - loss: 0.4608
# Epoch 14: val_accuracy improved from 0.85380 to 0.85530, saving model to best_cifar10_model.keras
#
# Epoch 14: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 269ms/step - accuracy: 0.8394 - loss: 0.4659 - val_accuracy: 0.8553 - val_loss: 0.4106 - learning_rate: 5.0000e-04
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8424 - loss: 0.4527
# Epoch 15: val_accuracy did not improve from 0.85530
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 255ms/step - accuracy: 0.8429 - loss: 0.4531 - val_accuracy: 0.8245 - val_loss: 0.5087 - learning_rate: 5.0000e-04
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.8471 - loss: 0.4395
# Epoch 16: val_accuracy improved from 0.85530 to 0.86030, saving model to best_cifar10_model.keras
#
# Epoch 16: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 80s 255ms/step - accuracy: 0.8466 - loss: 0.4433 - val_accuracy: 0.8603 - val_loss: 0.4127 - learning_rate: 5.0000e-04
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8510 - loss: 0.4268
# Epoch 17: val_accuracy did not improve from 0.86030
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 76s 244ms/step - accuracy: 0.8468 - loss: 0.4341 - val_accuracy: 0.8569 - val_loss: 0.4182 - learning_rate: 5.0000e-04
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.8619 - loss: 0.4040
# Epoch 18: val_accuracy improved from 0.86030 to 0.88310, saving model to best_cifar10_model.keras
#
# Epoch 18: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 245ms/step - accuracy: 0.8620 - loss: 0.3998 - val_accuracy: 0.8831 - val_loss: 0.3395 - learning_rate: 2.5000e-04
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8655 - loss: 0.3950
# Epoch 19: val_accuracy improved from 0.88310 to 0.89820, saving model to best_cifar10_model.keras
#
# Epoch 19: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 75s 239ms/step - accuracy: 0.8634 - loss: 0.3970 - val_accuracy: 0.8982 - val_loss: 0.3028 - learning_rate: 2.5000e-04
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8719 - loss: 0.3817
# Epoch 20: val_accuracy did not improve from 0.89820
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 74s 236ms/step - accuracy: 0.8689 - loss: 0.3851 - val_accuracy: 0.8950 - val_loss: 0.3116 - learning_rate: 2.5000e-04
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - accuracy: 0.8711 - loss: 0.3776
# Epoch 21: val_accuracy improved from 0.89820 to 0.90770, saving model to best_cifar10_model.keras
#
# Epoch 21: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 74s 237ms/step - accuracy: 0.8686 - loss: 0.3805 - val_accuracy: 0.9077 - val_loss: 0.2828 - learning_rate: 2.5000e-04
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - accuracy: 0.8682 - loss: 0.3738
# Epoch 22: val_accuracy did not improve from 0.90770
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 74s 236ms/step - accuracy: 0.8684 - loss: 0.3749 - val_accuracy: 0.8896 - val_loss: 0.3248 - learning_rate: 2.5000e-04
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 0.8696 - loss: 0.3791
# Epoch 23: val_accuracy improved from 0.90770 to 0.91060, saving model to best_cifar10_model.keras
#
# Epoch 23: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 74s 235ms/step - accuracy: 0.8711 - loss: 0.3729 - val_accuracy: 0.9106 - val_loss: 0.2706 - learning_rate: 2.5000e-04
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.8744 - loss: 0.3621
# Epoch 24: val_accuracy did not improve from 0.91060
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 83s 239ms/step - accuracy: 0.8745 - loss: 0.3645 - val_accuracy: 0.8990 - val_loss: 0.3014 - learning_rate: 2.5000e-04
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.8772 - loss: 0.3601
# Epoch 25: val_accuracy did not improve from 0.91060
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 245ms/step - accuracy: 0.8752 - loss: 0.3620 - val_accuracy: 0.9103 - val_loss: 0.2654 - learning_rate: 2.5000e-04
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.8757 - loss: 0.3600
# Epoch 26: val_accuracy did not improve from 0.91060
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 76s 243ms/step - accuracy: 0.8762 - loss: 0.3564 - val_accuracy: 0.9044 - val_loss: 0.2865 - learning_rate: 2.5000e-04
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.8798 - loss: 0.3461
# Epoch 27: val_accuracy did not improve from 0.91060
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 76s 244ms/step - accuracy: 0.8797 - loss: 0.3489 - val_accuracy: 0.9035 - val_loss: 0.2843 - learning_rate: 2.5000e-04
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.8775 - loss: 0.3500
# Epoch 28: val_accuracy improved from 0.91060 to 0.92350, saving model to best_cifar10_model.keras
#
# Epoch 28: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 249ms/step - accuracy: 0.8765 - loss: 0.3534 - val_accuracy: 0.9235 - val_loss: 0.2411 - learning_rate: 2.5000e-04
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - accuracy: 0.8809 - loss: 0.3445
# Epoch 29: val_accuracy did not improve from 0.92350
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 248ms/step - accuracy: 0.8791 - loss: 0.3483 - val_accuracy: 0.8989 - val_loss: 0.2909 - learning_rate: 2.5000e-04
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.8840 - loss: 0.3336
# Epoch 30: val_accuracy did not improve from 0.92350
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 251ms/step - accuracy: 0.8806 - loss: 0.3432 - val_accuracy: 0.9148 - val_loss: 0.2542 - learning_rate: 2.5000e-04
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8806 - loss: 0.3398
# Epoch 31: val_accuracy did not improve from 0.92350
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 76s 243ms/step - accuracy: 0.8804 - loss: 0.3417 - val_accuracy: 0.9208 - val_loss: 0.2444 - learning_rate: 2.5000e-04
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.8896 - loss: 0.3193
# Epoch 32: val_accuracy improved from 0.92350 to 0.92740, saving model to best_cifar10_model.keras
#
# Epoch 32: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 246ms/step - accuracy: 0.8886 - loss: 0.3234 - val_accuracy: 0.9274 - val_loss: 0.2212 - learning_rate: 1.2500e-04
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - accuracy: 0.8908 - loss: 0.3217
# Epoch 33: val_accuracy did not improve from 0.92740
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 252ms/step - accuracy: 0.8892 - loss: 0.3214 - val_accuracy: 0.9265 - val_loss: 0.2298 - learning_rate: 1.2500e-04
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.8932 - loss: 0.3128
# Epoch 34: val_accuracy improved from 0.92740 to 0.92820, saving model to best_cifar10_model.keras
#
# Epoch 34: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 254ms/step - accuracy: 0.8907 - loss: 0.3188 - val_accuracy: 0.9282 - val_loss: 0.2207 - learning_rate: 1.2500e-04
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - accuracy: 0.8927 - loss: 0.3088
# Epoch 35: val_accuracy improved from 0.92820 to 0.93110, saving model to best_cifar10_model.keras
#
# Epoch 35: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 251ms/step - accuracy: 0.8902 - loss: 0.3153 - val_accuracy: 0.9311 - val_loss: 0.2145 - learning_rate: 1.2500e-04
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step - accuracy: 0.8931 - loss: 0.3103
# Epoch 36: val_accuracy did not improve from 0.93110
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 75s 239ms/step - accuracy: 0.8904 - loss: 0.3136 - val_accuracy: 0.9295 - val_loss: 0.2116 - learning_rate: 1.2500e-04
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - accuracy: 0.8941 - loss: 0.3080
# Epoch 37: val_accuracy improved from 0.93110 to 0.93730, saving model to best_cifar10_model.keras
#
# Epoch 37: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 247ms/step - accuracy: 0.8930 - loss: 0.3103 - val_accuracy: 0.9373 - val_loss: 0.2000 - learning_rate: 1.2500e-04
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - accuracy: 0.8959 - loss: 0.3062
# Epoch 38: val_accuracy did not improve from 0.93730
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 249ms/step - accuracy: 0.8952 - loss: 0.3067 - val_accuracy: 0.9290 - val_loss: 0.2261 - learning_rate: 1.2500e-04
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.8954 - loss: 0.3048
# Epoch 39: val_accuracy did not improve from 0.93730
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 79s 254ms/step - accuracy: 0.8946 - loss: 0.3043 - val_accuracy: 0.9360 - val_loss: 0.2096 - learning_rate: 1.2500e-04
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.8943 - loss: 0.3080
# Epoch 40: val_accuracy did not improve from 0.93730
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 233ms/step - accuracy: 0.8923 - loss: 0.3086 - val_accuracy: 0.9350 - val_loss: 0.2059 - learning_rate: 1.2500e-04
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9022 - loss: 0.2879
# Epoch 41: val_accuracy did not improve from 0.93730
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 247ms/step - accuracy: 0.8979 - loss: 0.2943 - val_accuracy: 0.9373 - val_loss: 0.1956 - learning_rate: 6.2500e-05
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.8964 - loss: 0.3010
# Epoch 42: val_accuracy improved from 0.93730 to 0.93930, saving model to best_cifar10_model.keras
#
# Epoch 42: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 76s 242ms/step - accuracy: 0.8973 - loss: 0.2959 - val_accuracy: 0.9393 - val_loss: 0.1957 - learning_rate: 6.2500e-05
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.8965 - loss: 0.2967
# Epoch 43: val_accuracy improved from 0.93930 to 0.94200, saving model to best_cifar10_model.keras
#
# Epoch 43: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 247ms/step - accuracy: 0.8978 - loss: 0.2947 - val_accuracy: 0.9420 - val_loss: 0.1830 - learning_rate: 6.2500e-05
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9004 - loss: 0.2917
# Epoch 44: val_accuracy did not improve from 0.94200
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 78s 251ms/step - accuracy: 0.8986 - loss: 0.2901 - val_accuracy: 0.9390 - val_loss: 0.1939 - learning_rate: 6.2500e-05
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.9002 - loss: 0.2907
# Epoch 45: val_accuracy improved from 0.94200 to 0.94420, saving model to best_cifar10_model.keras
#
# Epoch 45: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 73s 234ms/step - accuracy: 0.9003 - loss: 0.2898 - val_accuracy: 0.9442 - val_loss: 0.1877 - learning_rate: 6.2500e-05
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - accuracy: 0.8972 - loss: 0.2973
# Epoch 46: val_accuracy improved from 0.94420 to 0.94650, saving model to best_cifar10_model.keras
#
# Epoch 46: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 89s 282ms/step - accuracy: 0.8987 - loss: 0.2927 - val_accuracy: 0.9465 - val_loss: 0.1766 - learning_rate: 6.2500e-05
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.8962 - loss: 0.2903
# Epoch 47: val_accuracy did not improve from 0.94650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 77s 245ms/step - accuracy: 0.8983 - loss: 0.2909 - val_accuracy: 0.9399 - val_loss: 0.1896 - learning_rate: 6.2500e-05
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 0.9032 - loss: 0.2850
# Epoch 48: val_accuracy did not improve from 0.94650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 268ms/step - accuracy: 0.9017 - loss: 0.2871 - val_accuracy: 0.9434 - val_loss: 0.1836 - learning_rate: 6.2500e-05
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.9040 - loss: 0.2830
# Epoch 49: val_accuracy did not improve from 0.94650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 76s 243ms/step - accuracy: 0.9032 - loss: 0.2842 - val_accuracy: 0.9347 - val_loss: 0.2009 - learning_rate: 6.2500e-05
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9021 - loss: 0.2840
# Epoch 50: val_accuracy did not improve from 0.94650
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 76s 242ms/step - accuracy: 0.9021 - loss: 0.2842 - val_accuracy: 0.9416 - val_loss: 0.1845 - learning_rate: 3.1250e-05

# %%
# 평가
_, acc = model.evaluate(X_test, y_test)
print(f'정확도 : {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8472 - loss: 0.4659
# 정확도 : 0.8471999764442444

# %%
# 성능 시각화
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# 이미지 시각화
predictions = model.predict(X_test[:16])
fig, axes = plt.subplots(4, 4, figsize=(8,8))
for i, ax in enumerate(axes.flat):
	
	ax.imshow(X_test[i])
	predict = predictions[i].argmax()
	true = y_test[i][0]
	ax.set_title(f"{class_names[predict]},{class_names[true]}")
	ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step

# %%
import cv2
import numpy as np
# 예측
def model_predict_idx(model, img_path):

	img = cv2.imread(img_path, cv2.IMREAD_COLOR)

	resize_img = cv2.resize(img, (32, 32))

	predict = model.predict(np.array([resize_img]))

	result = np.argmax(predict)
	return class_names[result]

# %%
# 예측
result = model_predict_idx(model, '../data/img/cifar10_0_1.png')
print(f'airplain? {result}')
result = model_predict_idx(model, '../data/img/cifar10_9_1.png')
print(f'truck? {result}')
result = model_predict_idx(model, '../data/img/cifar10_9_2.png')
print(f'truck? {result}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# airplain? airplane
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# truck? automobile
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# truck? automobile
