# %%
# 라이브러리 설치
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\c607\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\c607\anaconda3\lib\site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\c607\anaconda3\lib\site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\c607\anaconda3\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\c607\anaconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\c607\anaconda3\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\c607\anaconda3\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\c607\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\c607\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\c607\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\c607\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\c607\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\c607\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\c607\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\c607\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\c607\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\c607\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\c607\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\c607\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\C607\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\C607\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\C607\anaconda3\Lib\site-packages)

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# 데이터 생성
dataset = [
    ['우유', '빵', '사과'],
    ['우유', '빵', '주스'],
    ['우유', '빵', '기저귀'], # 우유와 빵은 단짝
    ['기저귀', '맥주', '소시지'],
    ['기저귀', '맥주', '땅콩'],
    ['기저귀', '맥주', '우유'], # 기저귀와 맥주는 단짝
    ['콜라', '과자', '주스'],
    ['콜라', '과자', '맥주'],
    ['콜라', '과자', '사과'], # 콜라와 과자는 단짝
    ['우유', '빵', '기저귀', '맥주'] # 혼합 구매
]

# %%
# 전처리: 리스트를 행렬 형태로 변환
te = TransactionEncoder()
te_ary = te.fit_transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
# 최소 지지도 설정하여 아이템 세트 추출
min_support = 0.2
frequent_itemsets = apriori(df, min_support=min_support, use_colnames=True)

# %%
# 최소 신뢰도를 이용해서 규칙 생성
min_threshold = 0.7
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_threshold)

# %%
# 결과 확인 (필요한 컬럼만 보기)
print(rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#   antecedents consequents  support  confidence      lift
# 0        (콜라)        (과자)      0.3         1.0  3.333333
# 1        (과자)        (콜라)      0.3         1.0  3.333333
# 2        (맥주)       (기저귀)      0.4         0.8  1.600000
# 3       (기저귀)        (맥주)      0.4         0.8  1.600000
# 4         (빵)        (우유)      0.4         1.0  2.000000
# 5        (우유)         (빵)      0.4         0.8  2.000000
# 6    (맥주, 우유)       (기저귀)      0.2         1.0  2.000000
# 7    (빵, 기저귀)        (우유)      0.2         1.0  2.000000
