# %%
import tensorflow as tf
from tensorflow.keras import layers, models, datasets
import numpy as np

# %%
# mnist에서 제공한 fashion 예제
(X_train, y_train), (X_test, y_test) = datasets.fashion_mnist.load_data()

# %%
# X_test, y_test를 이용해서 평가를 하고, X_test, y_test 중 16개를 가져와서 예측
# 학습은 1에포크만 적용(이유 시간 때문에)
# 분류는 총 10개
class_names = [
	'T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
	'Sandal', 'shirt', 'Sneaker', 'Bag', 'Ankle boot'
]

# %%
# 예측을 하면 분류 수만큼 확률이 나옴
# 왜? 모델 설계에서 출력층 활성화 함수가 softmax
# 가장 확률이 높은 분류 번호  => 타이틀
class_names = [
	'T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 
	'Sandal', 'shirt', 'Sneaker', 'Bag', 'Ankle boot'
]

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# 콜백
callbacks = [
	# 조기 종료
	EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
	# 가장 좋았던 성능을 저장 => 중간에 중지해도 중지전까지 최고 성능을 가져옴
	ModelCheckpoint(filepath='best_fs_mnist_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1),
	# 학습률을 고정 값이 아닌 상황에 따라 줄어들도록 조절
	ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
]

# %%
# 파이프라인 : 성능 향상 <= 학습 중에 다음 학습 데이터를 준비
from tensorflow.data import Dataset

DATASET_SIZE = 60000
TRAIN_SIZE = int(DATASET_SIZE * 0.8)
VAL_SIZE = int(DATASET_SIZE * 0.2)

dataset = Dataset.from_tensor_slices((X_train, y_train))
# 섞음 
dataset = dataset.shuffle(buffer_size=DATASET_SIZE)
# 훈련 데이터셋
train_dataset = dataset.take(TRAIN_SIZE)
# 검증 데이터셋
val_dataset = dataset.skip(TRAIN_SIZE)

train_dataset = train_dataset.batch(128).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(128).prefetch(tf.data.AUTOTUNE)

# %%
# 데이터 증강 => 다양한 형태의 이미지를 준비하지 않아도 생성해서 학습할 수 있도록
data_augmentation = tf.keras.Sequential([
	tf.keras.layers.RandomFlip("horizontal"), # 좌우 반전
	tf.keras.layers.RandomRotation(0.2) # 20% 범위 내에서 무작위 회전
])

# %%
# 모델 설계
model = tf.keras.models.Sequential([
	tf.keras.Input((28, 28, 1)),
	# 데이터 증강 
	data_augmentation, 
	# 정규화
	tf.keras.layers.Rescaling(1./255),

	tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	# tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2), # 압축
	tf.keras.layers.Dropout(0.25),
	# 이 때 이미지 크기 16 x 16

	# 블록 2
	tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	# tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Dropout(0.25),
	# 이 때 이미지 크기 8 x 8

	# 블록 3
	# tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.GlobalAveragePooling2D(),

	# 분류기
	tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 모델 설정
model.compile(
	optimizer='adam', 
	loss='sparse_categorical_crossentropy', # 활성화 함수가 softmax인데 값이 0, 1, 2, 3,...로 구분되어야되니까 원핫인코딩이면 지워야됨
	metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# 학습
history = model.fit(
	train_dataset,
	epochs = 30,
	verbose = 1,
	validation_data=val_dataset,
	callbacks = callbacks,
	batch_size=128,
)
# Out:
# Epoch 1/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.4237 - loss: 1.6572
# Epoch 1: val_accuracy improved from None to 0.09858, saving model to best_fs_mnist_model.keras
#
# Epoch 1: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 71s 161ms/step - accuracy: 0.5250 - loss: 1.4164 - val_accuracy: 0.0986 - val_loss: 3.4596 - learning_rate: 0.0010
# Epoch 2/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.6456 - loss: 1.0834
# Epoch 2: val_accuracy improved from 0.09858 to 0.52275, saving model to best_fs_mnist_model.keras
#
# Epoch 2: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 158ms/step - accuracy: 0.6568 - loss: 1.0423 - val_accuracy: 0.5228 - val_loss: 1.3198 - learning_rate: 0.0010
# Epoch 3/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.6833 - loss: 0.9393
# Epoch 3: val_accuracy improved from 0.52275 to 0.68883, saving model to best_fs_mnist_model.keras
#
# Epoch 3: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 126ms/step - accuracy: 0.6876 - loss: 0.9191 - val_accuracy: 0.6888 - val_loss: 0.9189 - learning_rate: 0.0010
# Epoch 4/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7040 - loss: 0.8655
# Epoch 4: val_accuracy improved from 0.68883 to 0.69050, saving model to best_fs_mnist_model.keras
#
# Epoch 4: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 161ms/step - accuracy: 0.7072 - loss: 0.8515 - val_accuracy: 0.6905 - val_loss: 0.8858 - learning_rate: 0.0010
# Epoch 5/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7155 - loss: 0.8157
# Epoch 5: val_accuracy did not improve from 0.69050
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 82s 160ms/step - accuracy: 0.7187 - loss: 0.8099 - val_accuracy: 0.6735 - val_loss: 0.9885 - learning_rate: 0.0010
# Epoch 6/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7229 - loss: 0.7897
# Epoch 6: val_accuracy did not improve from 0.69050
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.7285 - loss: 0.7784 - val_accuracy: 0.6863 - val_loss: 1.0145 - learning_rate: 0.0010
# Epoch 7/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7366 - loss: 0.7564
# Epoch 7: val_accuracy did not improve from 0.69050
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.7358 - loss: 0.7551 - val_accuracy: 0.6698 - val_loss: 0.8845 - learning_rate: 0.0010
# Epoch 8/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.7396 - loss: 0.7451
# Epoch 8: val_accuracy improved from 0.69050 to 0.74483, saving model to best_fs_mnist_model.keras
#
# Epoch 8: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 80s 156ms/step - accuracy: 0.7408 - loss: 0.7374 - val_accuracy: 0.7448 - val_loss: 0.7940 - learning_rate: 0.0010
# Epoch 9/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7440 - loss: 0.7260
# Epoch 9: val_accuracy improved from 0.74483 to 0.75975, saving model to best_fs_mnist_model.keras
#
# Epoch 9: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.7455 - loss: 0.7231 - val_accuracy: 0.7598 - val_loss: 0.6865 - learning_rate: 0.0010
# Epoch 10/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7505 - loss: 0.7115
# Epoch 10: val_accuracy did not improve from 0.75975
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 160ms/step - accuracy: 0.7506 - loss: 0.7098 - val_accuracy: 0.7551 - val_loss: 0.7256 - learning_rate: 0.0010
# Epoch 11/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7547 - loss: 0.6952
# Epoch 11: val_accuracy did not improve from 0.75975
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.7545 - loss: 0.6983 - val_accuracy: 0.7272 - val_loss: 0.8170 - learning_rate: 0.0010
# Epoch 12/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7564 - loss: 0.6907
# Epoch 12: val_accuracy improved from 0.75975 to 0.77317, saving model to best_fs_mnist_model.keras
#
# Epoch 12: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.7597 - loss: 0.6871 - val_accuracy: 0.7732 - val_loss: 0.6428 - learning_rate: 0.0010
# Epoch 13/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7562 - loss: 0.6929
# Epoch 13: val_accuracy did not improve from 0.77317
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.7572 - loss: 0.6858 - val_accuracy: 0.5392 - val_loss: 1.2412 - learning_rate: 0.0010
# Epoch 14/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - accuracy: 0.7595 - loss: 0.6797
# Epoch 14: val_accuracy did not improve from 0.77317
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.7606 - loss: 0.6734 - val_accuracy: 0.7708 - val_loss: 0.6386 - learning_rate: 0.0010
# Epoch 15/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7623 - loss: 0.6751
# Epoch 15: val_accuracy did not improve from 0.77317
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 163ms/step - accuracy: 0.7632 - loss: 0.6739 - val_accuracy: 0.6183 - val_loss: 1.0656 - learning_rate: 0.0010
# Epoch 16/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.7668 - loss: 0.6540
# Epoch 16: val_accuracy did not improve from 0.77317
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 160ms/step - accuracy: 0.7646 - loss: 0.6608 - val_accuracy: 0.7344 - val_loss: 0.7675 - learning_rate: 0.0010
# Epoch 17/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.7699 - loss: 0.6551
# Epoch 17: val_accuracy did not improve from 0.77317
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 66s 176ms/step - accuracy: 0.7689 - loss: 0.6556 - val_accuracy: 0.7477 - val_loss: 0.7079 - learning_rate: 0.0010
# Epoch 18/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7734 - loss: 0.6442
# Epoch 18: val_accuracy did not improve from 0.77317
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.7731 - loss: 0.6436 - val_accuracy: 0.7606 - val_loss: 0.6748 - learning_rate: 5.0000e-04
# Epoch 19/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7743 - loss: 0.6407
# Epoch 19: val_accuracy improved from 0.77317 to 0.78208, saving model to best_fs_mnist_model.keras
#
# Epoch 19: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 62s 164ms/step - accuracy: 0.7745 - loss: 0.6350 - val_accuracy: 0.7821 - val_loss: 0.6228 - learning_rate: 5.0000e-04
# Epoch 20/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7759 - loss: 0.6379
# Epoch 20: val_accuracy did not improve from 0.78208
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 161ms/step - accuracy: 0.7748 - loss: 0.6393 - val_accuracy: 0.7602 - val_loss: 0.6878 - learning_rate: 5.0000e-04
# Epoch 21/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7761 - loss: 0.6321
# Epoch 21: val_accuracy did not improve from 0.78208
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.7762 - loss: 0.6322 - val_accuracy: 0.7642 - val_loss: 0.6709 - learning_rate: 5.0000e-04
# Epoch 22/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7791 - loss: 0.6321
# Epoch 22: val_accuracy did not improve from 0.78208
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.7785 - loss: 0.6299 - val_accuracy: 0.7367 - val_loss: 0.7416 - learning_rate: 5.0000e-04
# Epoch 23/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.7793 - loss: 0.6217
# Epoch 23: val_accuracy did not improve from 0.78208
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 54s 142ms/step - accuracy: 0.7798 - loss: 0.6227 - val_accuracy: 0.7675 - val_loss: 0.6598 - learning_rate: 2.5000e-04
# Epoch 24/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.7841 - loss: 0.6130
# Epoch 24: val_accuracy improved from 0.78208 to 0.80400, saving model to best_fs_mnist_model.keras
#
# Epoch 24: finished saving model to best_fs_mnist_model.keras
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 63s 167ms/step - accuracy: 0.7846 - loss: 0.6114 - val_accuracy: 0.8040 - val_loss: 0.5587 - learning_rate: 2.5000e-04
# Epoch 25/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7846 - loss: 0.6143
# Epoch 25: val_accuracy did not improve from 0.80400
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 60s 159ms/step - accuracy: 0.7816 - loss: 0.6206 - val_accuracy: 0.7906 - val_loss: 0.5940 - learning_rate: 2.5000e-04
# Epoch 26/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7788 - loss: 0.6222
# Epoch 26: val_accuracy did not improve from 0.80400
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.7804 - loss: 0.6196 - val_accuracy: 0.7983 - val_loss: 0.5883 - learning_rate: 2.5000e-04
# Epoch 27/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.7771 - loss: 0.6151
# Epoch 27: val_accuracy did not improve from 0.80400
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 157ms/step - accuracy: 0.7795 - loss: 0.6158 - val_accuracy: 0.7928 - val_loss: 0.5983 - learning_rate: 2.5000e-04
# Epoch 28/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.7902 - loss: 0.6058
# Epoch 28: val_accuracy did not improve from 0.80400
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 61s 162ms/step - accuracy: 0.7871 - loss: 0.6083 - val_accuracy: 0.7688 - val_loss: 0.6594 - learning_rate: 1.2500e-04
# Epoch 29/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.7858 - loss: 0.6060
# Epoch 29: val_accuracy did not improve from 0.80400
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 59s 156ms/step - accuracy: 0.7862 - loss: 0.6099 - val_accuracy: 0.7928 - val_loss: 0.5899 - learning_rate: 1.2500e-04

# %%
# 모델 불러오기
model = tf.keras.models.load_model('best_fs_mnist_model.keras')

# %%
# 평가
_, acc = model.evaluate(X_test, y_test)
print(f'정확도 : {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.7969 - loss: 0.5968
# 정확도 : 0.7968999743461609

# %%
# 성능 시각화
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# 이미지 시각화
predictions = model.predict(X_test[:16])
fig, axes = plt.subplots(4, 4, figsize=(8,8))
for i, ax in enumerate(axes.flat):
	
	ax.imshow(X_test[i])
	predict_idx = predictions[i].argmax() # 확률이 가장 높은 값(번지)
	predict_name = class_names[predict_idx] # 확률이 가장 높은 분류명
	real_idx = y_test[i] # 실제 값(번지)
	real_name = class_names[real_idx]
	ax.set_title(f"{predict_name},{real_name}")
	ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
