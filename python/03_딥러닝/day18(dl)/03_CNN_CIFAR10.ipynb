# %%
# CIFAR : 캐나다 고등 연구소 약자
# 10 : 분류 10개
# - 비행기, 자동차, 새, 고양이, 사슴, 개, 개구리, 말, 배, 트럭
# 이미지 총 6만장. 학습 5만, 테스트 1만
# 크기 32 x 32

# %%
# 데이터 생성, 독립/종속 분리, 훈련/테스트 분리
import tensorflow as tf
(X_train, y_train), (X_test, y_test) = tf.keras.datasets.cifar10.load_data()

# %%
# 10가지 분류명(확인용)
class_names = [
	'airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck'
]

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
# 콜백
callbacks = [
	EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True),
	ModelCheckpoint(filepath='best_cifar10_model.keras', monitor='val_accuracy', save_best_only=True, verbose=1),
	ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
]

# %%
# 파이프라인
from tensorflow.data import Dataset

DATASET_SIZE = 50000
TRAIN_SIZE = int(DATASET_SIZE * 0.8)
VAL_SIZE = int(DATASET_SIZE * 0.2)

dataset = Dataset.from_tensor_slices((X_train, y_train))
# 섞음 
dataset = dataset.shuffle(buffer_size=DATASET_SIZE)
# 훈련 데이터셋
train_dataset = dataset.take(TRAIN_SIZE)
# 검증 데이터셋
val_dataset = dataset.skip(TRAIN_SIZE)

train_dataset = train_dataset.batch(128).prefetch(tf.data.AUTOTUNE)
val_dataset = val_dataset.batch(128).prefetch(tf.data.AUTOTUNE)

# %%
# 데이터 증강 : 이미지를 돌리거나, 색상 반전등과 같이 변형을 한 복사본을 만들어 학습
data_augmentation = tf.keras.Sequential([
	tf.keras.layers.RandomFlip("horizontal"), # 좌우 반전
	tf.keras.layers.RandomRotation(0.2) # 20% 범위 내에서 무작위 회전
])

# %%
# 모델 설계
model = tf.keras.models.Sequential([
	tf.keras.Input((32, 32, 3)),
	# 데이터 증강 
	# data_augmentation, 
	# 정규화
	tf.keras.layers.Rescaling(1./255),

	tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.Conv2D(32, (3,3), padding='same', activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Dropout(0.25),
	# 이 때 이미지 크기 16 x 16

	# 블록 2
	tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.Conv2D(64, (3,3), padding='same', activation='relu'),
	tf.keras.layers.MaxPooling2D(2,2),
	tf.keras.layers.Dropout(0.25),
	# 이 때 이미지 크기 8 x 8

	# 블록 3
	tf.keras.layers.Conv2D(128, (3,3), padding='same', activation='relu'),
	tf.keras.layers.BatchNormalization(),
	tf.keras.layers.GlobalAveragePooling2D(),

	# 분류기
	tf.keras.layers.Dense(10, activation='softmax')
])

# %%
# 모델 설정
model.compile(
	optimizer='adam', 
	loss='sparse_categorical_crossentropy', 
	metrics=['accuracy']
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# 학습
history = model.fit(
	train_dataset,
	epochs = 50,
	verbose = 1,
	validation_data=val_dataset,
	callbacks = callbacks,
	batch_size=128,
)
# Out:
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.4128 - loss: 1.6145
# Epoch 1: val_accuracy improved from None to 0.13660, saving model to best_cifar10_model.keras
#
# Epoch 1: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 69s 209ms/step - accuracy: 0.4978 - loss: 1.3922 - val_accuracy: 0.1366 - val_loss: 4.7145 - learning_rate: 0.0010
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - accuracy: 0.6214 - loss: 1.0646
# Epoch 2: val_accuracy improved from 0.13660 to 0.56070, saving model to best_cifar10_model.keras
#
# Epoch 2: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 67s 212ms/step - accuracy: 0.6346 - loss: 1.0303 - val_accuracy: 0.5607 - val_loss: 1.1876 - learning_rate: 0.0010
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.6804 - loss: 0.9110
# Epoch 3: val_accuracy improved from 0.56070 to 0.62340, saving model to best_cifar10_model.keras
#
# Epoch 3: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 194ms/step - accuracy: 0.6867 - loss: 0.8906 - val_accuracy: 0.6234 - val_loss: 1.1258 - learning_rate: 0.0010
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.7184 - loss: 0.8095
# Epoch 4: val_accuracy improved from 0.62340 to 0.71140, saving model to best_cifar10_model.keras
#
# Epoch 4: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 62s 199ms/step - accuracy: 0.7220 - loss: 0.7954 - val_accuracy: 0.7114 - val_loss: 0.8105 - learning_rate: 0.0010
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.7424 - loss: 0.7337
# Epoch 5: val_accuracy did not improve from 0.71140
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 62s 199ms/step - accuracy: 0.7457 - loss: 0.7267 - val_accuracy: 0.6625 - val_loss: 0.9913 - learning_rate: 0.0010
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7660 - loss: 0.6742
# Epoch 6: val_accuracy improved from 0.71140 to 0.73510, saving model to best_cifar10_model.keras
#
# Epoch 6: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 60s 191ms/step - accuracy: 0.7666 - loss: 0.6730 - val_accuracy: 0.7351 - val_loss: 0.7582 - learning_rate: 0.0010
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7823 - loss: 0.6263
# Epoch 7: val_accuracy improved from 0.73510 to 0.76560, saving model to best_cifar10_model.keras
#
# Epoch 7: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 193ms/step - accuracy: 0.7821 - loss: 0.6238 - val_accuracy: 0.7656 - val_loss: 0.6945 - learning_rate: 0.0010
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.7990 - loss: 0.5841
# Epoch 8: val_accuracy did not improve from 0.76560
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 193ms/step - accuracy: 0.7958 - loss: 0.5906 - val_accuracy: 0.7251 - val_loss: 0.8112 - learning_rate: 0.0010
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - accuracy: 0.8059 - loss: 0.5640
# Epoch 9: val_accuracy improved from 0.76560 to 0.82270, saving model to best_cifar10_model.keras
#
# Epoch 9: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 58s 187ms/step - accuracy: 0.8043 - loss: 0.5652 - val_accuracy: 0.8227 - val_loss: 0.4976 - learning_rate: 0.0010
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - accuracy: 0.8196 - loss: 0.5255
# Epoch 10: val_accuracy did not improve from 0.82270
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 63s 203ms/step - accuracy: 0.8158 - loss: 0.5319 - val_accuracy: 0.7913 - val_loss: 0.6273 - learning_rate: 0.0010
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step - accuracy: 0.8226 - loss: 0.5094
# Epoch 11: val_accuracy did not improve from 0.82270
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 196ms/step - accuracy: 0.8191 - loss: 0.5201 - val_accuracy: 0.7925 - val_loss: 0.5823 - learning_rate: 0.0010
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - accuracy: 0.8269 - loss: 0.5071
# Epoch 12: val_accuracy improved from 0.82270 to 0.84110, saving model to best_cifar10_model.keras
#
# Epoch 12: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 63s 201ms/step - accuracy: 0.8264 - loss: 0.5052 - val_accuracy: 0.8411 - val_loss: 0.4560 - learning_rate: 0.0010
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.8350 - loss: 0.4788
# Epoch 13: val_accuracy improved from 0.84110 to 0.85610, saving model to best_cifar10_model.keras
#
# Epoch 13: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 60s 192ms/step - accuracy: 0.8340 - loss: 0.4819 - val_accuracy: 0.8561 - val_loss: 0.4186 - learning_rate: 0.0010
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8411 - loss: 0.4623
# Epoch 14: val_accuracy did not improve from 0.85610
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 58s 185ms/step - accuracy: 0.8381 - loss: 0.4698 - val_accuracy: 0.8363 - val_loss: 0.4866 - learning_rate: 0.0010
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8431 - loss: 0.4487
# Epoch 15: val_accuracy improved from 0.85610 to 0.85990, saving model to best_cifar10_model.keras
#
# Epoch 15: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 194ms/step - accuracy: 0.8422 - loss: 0.4526 - val_accuracy: 0.8599 - val_loss: 0.4035 - learning_rate: 0.0010
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.8517 - loss: 0.4311
# Epoch 16: val_accuracy improved from 0.85990 to 0.87570, saving model to best_cifar10_model.keras
#
# Epoch 16: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 58s 187ms/step - accuracy: 0.8495 - loss: 0.4376 - val_accuracy: 0.8757 - val_loss: 0.3606 - learning_rate: 0.0010
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.8552 - loss: 0.4174
# Epoch 17: val_accuracy did not improve from 0.87570
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 59s 188ms/step - accuracy: 0.8523 - loss: 0.4244 - val_accuracy: 0.8250 - val_loss: 0.4876 - learning_rate: 0.0010
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - accuracy: 0.8582 - loss: 0.4070
# Epoch 18: val_accuracy did not improve from 0.87570
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 61s 195ms/step - accuracy: 0.8547 - loss: 0.4170 - val_accuracy: 0.8720 - val_loss: 0.3710 - learning_rate: 0.0010
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - accuracy: 0.8576 - loss: 0.4067
# Epoch 19: val_accuracy did not improve from 0.87570
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 68s 218ms/step - accuracy: 0.8580 - loss: 0.4075 - val_accuracy: 0.8330 - val_loss: 0.4905 - learning_rate: 0.0010
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - accuracy: 0.8761 - loss: 0.3603
# Epoch 20: val_accuracy improved from 0.87570 to 0.90940, saving model to best_cifar10_model.keras
#
# Epoch 20: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 65s 208ms/step - accuracy: 0.8764 - loss: 0.3599 - val_accuracy: 0.9094 - val_loss: 0.2644 - learning_rate: 5.0000e-04
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - accuracy: 0.8781 - loss: 0.3536
# Epoch 21: val_accuracy improved from 0.90940 to 0.91370, saving model to best_cifar10_model.keras
#
# Epoch 21: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 96s 308ms/step - accuracy: 0.8788 - loss: 0.3529 - val_accuracy: 0.9137 - val_loss: 0.2611 - learning_rate: 5.0000e-04
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 0.8788 - loss: 0.3459
# Epoch 22: val_accuracy did not improve from 0.91370
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 69s 220ms/step - accuracy: 0.8798 - loss: 0.3471 - val_accuracy: 0.9069 - val_loss: 0.2734 - learning_rate: 5.0000e-04
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8865 - loss: 0.3276
# Epoch 23: val_accuracy improved from 0.91370 to 0.91600, saving model to best_cifar10_model.keras
#
# Epoch 23: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 84s 268ms/step - accuracy: 0.8839 - loss: 0.3342 - val_accuracy: 0.9160 - val_loss: 0.2499 - learning_rate: 5.0000e-04
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 0.8889 - loss: 0.3238
# Epoch 24: val_accuracy did not improve from 0.91600
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 86s 274ms/step - accuracy: 0.8852 - loss: 0.3361 - val_accuracy: 0.8938 - val_loss: 0.3144 - learning_rate: 5.0000e-04
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - accuracy: 0.8886 - loss: 0.3221
# Epoch 25: val_accuracy did not improve from 0.91600
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 62s 198ms/step - accuracy: 0.8861 - loss: 0.3272 - val_accuracy: 0.9140 - val_loss: 0.2505 - learning_rate: 5.0000e-04
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - accuracy: 0.8928 - loss: 0.3118
# Epoch 26: val_accuracy did not improve from 0.91600
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 70s 223ms/step - accuracy: 0.8896 - loss: 0.3201 - val_accuracy: 0.9150 - val_loss: 0.2530 - learning_rate: 5.0000e-04
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.8959 - loss: 0.2985
# Epoch 27: val_accuracy improved from 0.91600 to 0.93660, saving model to best_cifar10_model.keras
#
# Epoch 27: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 65s 207ms/step - accuracy: 0.8954 - loss: 0.2993 - val_accuracy: 0.9366 - val_loss: 0.1966 - learning_rate: 2.5000e-04
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9011 - loss: 0.2848
# Epoch 28: val_accuracy improved from 0.93660 to 0.93890, saving model to best_cifar10_model.keras
#
# Epoch 28: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 60s 190ms/step - accuracy: 0.8989 - loss: 0.2923 - val_accuracy: 0.9389 - val_loss: 0.1943 - learning_rate: 2.5000e-04
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step - accuracy: 0.9023 - loss: 0.2838
# Epoch 29: val_accuracy did not improve from 0.93890
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 62s 198ms/step - accuracy: 0.9012 - loss: 0.2897 - val_accuracy: 0.9385 - val_loss: 0.1943 - learning_rate: 2.5000e-04
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step - accuracy: 0.9034 - loss: 0.2825
# Epoch 30: val_accuracy did not improve from 0.93890
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 59s 188ms/step - accuracy: 0.9009 - loss: 0.2879 - val_accuracy: 0.9362 - val_loss: 0.1958 - learning_rate: 2.5000e-04
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.9034 - loss: 0.2819
# Epoch 31: val_accuracy improved from 0.93890 to 0.94030, saving model to best_cifar10_model.keras
#
# Epoch 31: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 66s 210ms/step - accuracy: 0.9033 - loss: 0.2821 - val_accuracy: 0.9403 - val_loss: 0.1850 - learning_rate: 2.5000e-04
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.9062 - loss: 0.2739
# Epoch 32: val_accuracy improved from 0.94030 to 0.94800, saving model to best_cifar10_model.keras
#
# Epoch 32: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 66s 211ms/step - accuracy: 0.9032 - loss: 0.2810 - val_accuracy: 0.9480 - val_loss: 0.1757 - learning_rate: 2.5000e-04
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step - accuracy: 0.9084 - loss: 0.2690
# Epoch 33: val_accuracy improved from 0.94800 to 0.94840, saving model to best_cifar10_model.keras
#
# Epoch 33: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 125s 400ms/step - accuracy: 0.9053 - loss: 0.2763 - val_accuracy: 0.9484 - val_loss: 0.1681 - learning_rate: 2.5000e-04
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step - accuracy: 0.9049 - loss: 0.2740
# Epoch 34: val_accuracy did not improve from 0.94840
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 124s 340ms/step - accuracy: 0.9058 - loss: 0.2736 - val_accuracy: 0.9481 - val_loss: 0.1631 - learning_rate: 2.5000e-04
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.9081 - loss: 0.2673
# Epoch 35: val_accuracy did not improve from 0.94840
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 122s 391ms/step - accuracy: 0.9058 - loss: 0.2709 - val_accuracy: 0.9410 - val_loss: 0.1807 - learning_rate: 2.5000e-04
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step - accuracy: 0.9068 - loss: 0.2716
# Epoch 36: val_accuracy did not improve from 0.94840
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 103s 328ms/step - accuracy: 0.9074 - loss: 0.2686 - val_accuracy: 0.9481 - val_loss: 0.1646 - learning_rate: 2.5000e-04
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step - accuracy: 0.9091 - loss: 0.2630
# Epoch 37: val_accuracy did not improve from 0.94840
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 125s 400ms/step - accuracy: 0.9067 - loss: 0.2677 - val_accuracy: 0.9430 - val_loss: 0.1819 - learning_rate: 2.5000e-04
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9107 - loss: 0.2610
# Epoch 38: val_accuracy improved from 0.94840 to 0.95250, saving model to best_cifar10_model.keras
#
# Epoch 38: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 127s 406ms/step - accuracy: 0.9136 - loss: 0.2544 - val_accuracy: 0.9525 - val_loss: 0.1514 - learning_rate: 1.2500e-04
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.9101 - loss: 0.2588
# Epoch 39: val_accuracy improved from 0.95250 to 0.95400, saving model to best_cifar10_model.keras
#
# Epoch 39: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 126s 402ms/step - accuracy: 0.9114 - loss: 0.2557 - val_accuracy: 0.9540 - val_loss: 0.1516 - learning_rate: 1.2500e-04
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9135 - loss: 0.2480
# Epoch 40: val_accuracy improved from 0.95400 to 0.96090, saving model to best_cifar10_model.keras
#
# Epoch 40: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 127s 407ms/step - accuracy: 0.9120 - loss: 0.2521 - val_accuracy: 0.9609 - val_loss: 0.1389 - learning_rate: 1.2500e-04
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9135 - loss: 0.2501
# Epoch 41: val_accuracy did not improve from 0.96090
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 135s 429ms/step - accuracy: 0.9146 - loss: 0.2480 - val_accuracy: 0.9598 - val_loss: 0.1388 - learning_rate: 1.2500e-04
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9158 - loss: 0.2442
# Epoch 42: val_accuracy improved from 0.96090 to 0.96220, saving model to best_cifar10_model.keras
#
# Epoch 42: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 127s 405ms/step - accuracy: 0.9148 - loss: 0.2462 - val_accuracy: 0.9622 - val_loss: 0.1334 - learning_rate: 1.2500e-04
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.9174 - loss: 0.2421
# Epoch 43: val_accuracy did not improve from 0.96220
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 129s 412ms/step - accuracy: 0.9158 - loss: 0.2465 - val_accuracy: 0.9551 - val_loss: 0.1466 - learning_rate: 1.2500e-04
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9194 - loss: 0.2404
# Epoch 44: val_accuracy did not improve from 0.96220
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 143s 413ms/step - accuracy: 0.9176 - loss: 0.2434 - val_accuracy: 0.9570 - val_loss: 0.1381 - learning_rate: 1.2500e-04
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9145 - loss: 0.2419
# Epoch 45: val_accuracy did not improve from 0.96220
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 127s 406ms/step - accuracy: 0.9143 - loss: 0.2436 - val_accuracy: 0.9603 - val_loss: 0.1339 - learning_rate: 1.2500e-04
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9194 - loss: 0.2384
# Epoch 46: val_accuracy did not improve from 0.96220
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 128s 408ms/step - accuracy: 0.9206 - loss: 0.2360 - val_accuracy: 0.9597 - val_loss: 0.1314 - learning_rate: 6.2500e-05
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.9193 - loss: 0.2327
# Epoch 47: val_accuracy improved from 0.96220 to 0.96470, saving model to best_cifar10_model.keras
#
# Epoch 47: finished saving model to best_cifar10_model.keras
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 72s 229ms/step - accuracy: 0.9186 - loss: 0.2351 - val_accuracy: 0.9647 - val_loss: 0.1258 - learning_rate: 6.2500e-05
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.9178 - loss: 0.2358
# Epoch 48: val_accuracy did not improve from 0.96470
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 60s 192ms/step - accuracy: 0.9182 - loss: 0.2354 - val_accuracy: 0.9638 - val_loss: 0.1285 - learning_rate: 6.2500e-05
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step - accuracy: 0.9168 - loss: 0.2367
# Epoch 49: val_accuracy did not improve from 0.96470
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 60s 193ms/step - accuracy: 0.9183 - loss: 0.2358 - val_accuracy: 0.9622 - val_loss: 0.1292 - learning_rate: 6.2500e-05
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - accuracy: 0.9195 - loss: 0.2314
# Epoch 50: val_accuracy did not improve from 0.96470
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 59s 189ms/step - accuracy: 0.9190 - loss: 0.2334 - val_accuracy: 0.9636 - val_loss: 0.1251 - learning_rate: 6.2500e-05

# %%
# 평가
_, acc = model.evaluate(X_test, y_test)
print(f'정확도 : {acc}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - accuracy: 0.8601 - loss: 0.4354
# 정확도 : 0.8600999712944031

# %%
# 성능 시각화
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'], label='Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
# 이미지 시각화
predictions = model.predict(X_test[:16])
fig, axes = plt.subplots(4, 4, figsize=(8,8))
for i, ax in enumerate(axes.flat):
	
	ax.imshow(X_test[i])
	predict = predictions[i].argmax()
	true = y_test[i][0]
	ax.set_title(f"{class_names[predict]},{class_names[true]}")
	ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step

# %%
import cv2
import numpy as np
# 예측
def model_predict_idx(model, img_path):

	img = cv2.imread(img_path, cv2.IMREAD_COLOR)

	resize_img = cv2.resize(img, (32, 32))

	predict = model.predict(np.array([resize_img]))

	result = np.argmax(predict)
	return class_names[result]

# %%
# 예측
result = model_predict_idx(model, '../data/img/cifar10_0_1.png')
print(f'airplain? {result}')
result = model_predict_idx(model, '../data/img/cifar10_9_1.png')
print(f'truck? {result}')
result = model_predict_idx(model, '../data/img/cifar10_9_2.png')
print(f'truck? {result}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# airplain? airplane
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# truck? automobile
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# truck? automobile
